# %%
import re
import pandas as pd
import numpy as np
from PyPDF2 import PdfReader
import json
import os
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import DirectoryLoader, PyPDFLoader
from tqdm.notebook import tqdm
from langchain.schema import Document

# %%
uu_file_path = "../data/UU Nomor 13 Tahun 2003.pdf"
print(f"File UU No. 13 Tahun 2003 sudah ada di {uu_file_path}")
# Out:
# File UU No. 13 Tahun 2003 sudah ada di ../data/UU Nomor 13 Tahun 2003.pdf

# %%
loader = PyPDFLoader(uu_file_path)
documents = loader.load()
print(f"Jumlah dokumen yang dimuat: {len(documents)}")
# Out:
# Jumlah dokumen yang dimuat: 128

# %%
try:
    with open('UU_Nomor_13_Tahun_2003_Ketenagakerjaan.txt', 'r', encoding='utf-8') as f:
        uu_text = f.read()
    print("Berhasil membaca file teks yang sudah ada.")
except:
    print("File teks tidak ditemukan. Menggunakan teks yang ada di variabel.")
# Out:
# File teks tidak ditemukan. Menggunakan teks yang ada di variabel.

# %% [markdown]
# Teknik Chunking dengan Mempertahankan Struktur Bab, Pasal, dan Ayat

# %%
def extract_structure(text):
    """
    Mengekstrak struktur UU menjadi dict dengan struktur bab, pasal, dan ayat
    """
    # Pola untuk mendeteksi BAB
    bab_pattern = r'BAB\s+([IVXLCDM]+)\s*\n(.*?)\n'
    
    # Pola untuk mendeteksi Pasal
    pasal_pattern = r'Pasal\s+(\d+)\s*\n'
    
    # Pola untuk mendeteksi Ayat
    ayat_pattern = r'\((\d+)\)\s+'
    
    structured_law = {}
    current_bab = None
    current_pasal = None
    
    # Split text berdasarkan baris
    lines = text.split('\n')
    i = 0
    
    while i < len(lines):
        line = lines[i]
        
        # Cek apakah ini adalah BAB baru
        bab_match = re.search(r'BAB\s+([IVXLCDM]+)', line)
        if bab_match:
            # Jika ada baris selanjutnya yang merupakan judul BAB
            if i + 1 < len(lines) and not re.search(r'BAB\s+([IVXLCDM]+)', lines[i+1]):
                current_bab = f"BAB {bab_match.group(1)}: {lines[i+1].strip()}"
                structured_law[current_bab] = {}
                i += 2
                continue
            else:
                current_bab = f"BAB {bab_match.group(1)}"
                structured_law[current_bab] = {}
        
        # Cek apakah ini adalah Pasal baru
        pasal_match = re.search(r'Pasal\s+(\d+)', line)
        if pasal_match and current_bab is not None:
            current_pasal = f"Pasal {pasal_match.group(1)}"
            structured_law[current_bab][current_pasal] = {"text": "", "ayat": {}}
            
            # Ambil isi pasal sampai menemukan pasal baru atau bab baru
            pasal_content = []
            j = i + 1
            while j < len(lines):
                next_line = lines[j]
                if re.search(r'Pasal\s+\d+', next_line) or re.search(r'BAB\s+[IVXLCDM]+', next_line):
                    break
                    
                # Deteksi Ayat
                ayat_match = re.search(r'^\s*\((\d+)\)\s+(.+)', next_line)
                if ayat_match:
                    ayat_num = ayat_match.group(1)
                    ayat_text = ayat_match.group(2)
                    
                    # Tambahkan ayat ke struktur
                    if current_pasal in structured_law[current_bab]:
                        structured_law[current_bab][current_pasal]["ayat"][f"Ayat {ayat_num}"] = ayat_text
                else:
                    pasal_content.append(next_line)
                
                j += 1
            
            # Gabungkan isi pasal
            if pasal_content:
                structured_law[current_bab][current_pasal]["text"] = "\n".join(pasal_content).strip()
                
            i = j - 1  # Sesuaikan iterator
        
        i += 1
    
    return structured_law

# %% [markdown]
# Fungsi untuk menghasilkan chunks dengan metadata struktur

# %%
def create_chunks_with_structure(text, chunk_size=500, chunk_overlap=50):
    
    # Membuat chunks dengan struktur Bab, Pasal, dan Ayat sebagai metadata
    # Ekstrak struktur terlebih dahulu
    structured_law = extract_structure(text)
    
    # Buat text splitter
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size, 
        chunk_overlap=chunk_overlap,
        separators=["\n\n", "\n", " ", ""]
    )
    
    # Proses chunks dengan metadata struktur
    chunks = []
    
    for bab, pasal_dict in structured_law.items():
        for pasal, content in pasal_dict.items():
            # Proses teks pasal
            pasal_text = content["text"]
            if pasal_text:
                pasal_chunks = text_splitter.create_documents(
                    [pasal_text], 
                    metadatas=[{
                        "source": "UU No 13 Tahun 2003",
                        "bab": bab,
                        "pasal": pasal,
                        "type": "pasal_text"
                    }]
                )
                chunks.extend(pasal_chunks)
            
            # Proses ayat-ayat
            for ayat, ayat_text in content["ayat"].items():
                ayat_chunks = text_splitter.create_documents(
                    [ayat_text], 
                    metadatas=[{
                        "source": "UU No 13 Tahun 2003",
                        "bab": bab,
                        "pasal": pasal,
                        "ayat": ayat,
                        "type": "ayat"
                    }]
                )
                chunks.extend(ayat_chunks)
    
    return chunks

# %% [markdown]
# Alternatif pendekatan chunking: Mempertahankan konteks lengkap

# %%
def create_context_aware_chunks(text, chunk_size=1000, chunk_overlap=200):
    """
    Membuat chunks dengan konteks hierarchy BAB > Bagian > Pasal > Ayat
    """
    # Pola-pola untuk deteksi struktur
    bab_pattern = r'BAB\s+([IVXLCDM]+)\s+([^\n]+)'
    bagian_pattern = r'Bagian\s+([A-Za-z0-9]+)\s+([^\n]+)'
    pasal_pattern = r'Pasal\s+(\d+)(\s+[^\n]+)?'
    ayat_pattern = r'\((\d+)\)\s+'
    
    # Split text berdasarkan baris
    lines = text.split('\n')
    
    chunks = []
    current_bab = None
    current_bagian = None
    current_pasal = None
    current_chunk_text = ""
    current_chunk_metadata = {}
    
    for line in lines:
        # Deteksi BAB baru
        bab_match = re.search(bab_pattern, line)
        if bab_match:
            # Simpan chunk sebelumnya jika ada
            if current_chunk_text and len(current_chunk_text) > 50:  # minimum 50 char untuk chunk
                chunks.append({
                    "text": current_chunk_text.strip(),
                    "metadata": current_chunk_metadata.copy()
                })
            
            # Mulai chunk baru untuk BAB
            current_bab = f"BAB {bab_match.group(1)}: {bab_match.group(2).strip()}"
            current_bagian = None  # Reset bagian
            current_pasal = None   # Reset pasal
            current_chunk_text = f"{current_bab}\n"
            current_chunk_metadata = {
                "source": "UU No 13 Tahun 2003",
                "bab": current_bab,
                "bagian": None,
                "pasal": None,
                "ayat": None,
                "type": "bab_title"
            }
            continue
        
        # Deteksi Bagian baru
        bagian_match = re.search(bagian_pattern, line)
        if bagian_match:
            # Simpan chunk sebelumnya jika ada
            if current_chunk_text and len(current_chunk_text) > 50:
                chunks.append({
                    "text": current_chunk_text.strip(),
                    "metadata": current_chunk_metadata.copy()
                })
            
            # Mulai chunk baru untuk Bagian
            current_bagian = f"Bagian {bagian_match.group(1)}: {bagian_match.group(2).strip()}"
            current_pasal = None  # Reset pasal
            current_chunk_text = f"{current_bagian}\n"
            current_chunk_metadata = {
                "source": "UU No 13 Tahun 2003",
                "bab": current_bab,
                "bagian": current_bagian,
                "pasal": None,
                "ayat": None,
                "type": "bagian_title"
            }
            continue
        
        # Deteksi Pasal baru
        pasal_match = re.search(pasal_pattern, line)
        if pasal_match:
            # Simpan chunk sebelumnya jika ada
            if current_chunk_text and len(current_chunk_text) > 50:
                chunks.append({
                    "text": current_chunk_text.strip(),
                    "metadata": current_chunk_metadata.copy()
                })
            
            # Mulai chunk baru untuk Pasal
            current_pasal = f"Pasal {pasal_match.group(1)}"
            current_chunk_text = f"{current_pasal}\n"
            current_chunk_metadata = {
                "source": "UU No 13 Tahun 2003",
                "bab": current_bab,
                "bagian": current_bagian,
                "pasal": current_pasal,
                "ayat": None,
                "type": "pasal_header"
            }
            continue
        
        # Deteksi Ayat
        ayat_match = re.search(ayat_pattern, line)
        if ayat_match and current_pasal:
            # Tambahkan ayat ke chunk saat ini
            ayat_num = ayat_match.group(1)
            ayat_content = line[ayat_match.end():]
            
            # Simpan chunk sebelumnya jika teksnya sudah panjang
            if len(current_chunk_text) > chunk_size:
                chunks.append({
                    "text": current_chunk_text.strip(),
                    "metadata": current_chunk_metadata.copy()
                })
                # Mulai chunk baru tapi pertahankan konteks
                current_chunk_text = f"{current_bab}\n{current_pasal}\n"
            
            current_chunk_text += f"({ayat_num}) {ayat_content}\n"
            current_chunk_metadata["ayat"] = f"Ayat {ayat_num}"
            current_chunk_metadata["type"] = "pasal_with_ayat"
            continue
        
        # Tambahkan line ke chunk saat ini
        if line.strip():
            current_chunk_text += line + "\n"
            
            # Cek jika chunk saat ini melebihi ukuran
            if len(current_chunk_text) > chunk_size + chunk_overlap:
                chunks.append({
                    "text": current_chunk_text[:chunk_size].strip(),
                    "metadata": current_chunk_metadata.copy()
                })
                # Simpan bagian yang overlap untuk chunk berikutnya
                current_chunk_text = current_chunk_text[chunk_size-chunk_overlap:]
    
    # Tambahkan chunk terakhir jika ada
    if current_chunk_text and len(current_chunk_text) > 50:
        chunks.append({
            "text": current_chunk_text.strip(),
            "metadata": current_chunk_metadata.copy()
        })
    
    return chunks

# %% [markdown]
# Jalankan proses chunking

# %%
# Metode 1: Chunks dengan struktur yang terekstrak
print("Melakukan chunking dengan struktur...")
# Gabungkan teks dari semua dokumen menjadi satu string
documents_text = "\n".join([doc.page_content for doc in documents])

# Lakukan chunking dengan struktur
chunks_structured = create_chunks_with_structure(documents_text, chunk_size=1000, chunk_overlap=100)
print(f"Dihasilkan {len(chunks_structured)} chunks dengan struktur.")
# Out:
# Melakukan chunking dengan struktur...
# Dihasilkan 671 chunks dengan struktur.

# %%
# Metode 2: Chunks dengan kesadaran konteks
print("Melakukan chunking dengan kesadaran konteks...")
chunks_context_aware = create_context_aware_chunks(documents_text, chunk_size=1000, chunk_overlap=200)
print(f"Dihasilkan {len(chunks_context_aware)} chunks dengan konteks.")
# Out:
# Melakukan chunking dengan kesadaran konteks...
# Dihasilkan 376 chunks dengan konteks.

# %%
# Konversi chunks struktur ke dataframe
def chunks_to_dataframe(chunks, method_name):
    if method_name == "structured":
        df = pd.DataFrame([{
            "text": chunk.page_content,
            "bab": chunk.metadata.get("bab", ""),
            "pasal": chunk.metadata.get("pasal", ""),
            "ayat": chunk.metadata.get("ayat", ""),
            "type": chunk.metadata.get("type", ""),
            "source": chunk.metadata.get("source", ""),
        } for chunk in chunks])
    else:
        df = pd.DataFrame([{
            "text": chunk["text"],
            "bab": chunk["metadata"].get("bab", ""),
            "bagian": chunk["metadata"].get("bagian", ""),
            "pasal": chunk["metadata"].get("pasal", ""),
            "ayat": chunk["metadata"].get("ayat", ""),
            "type": chunk["metadata"].get("type", ""),
            "source": chunk["metadata"].get("source", ""),
        } for chunk in chunks])
    
    return df

df_structured = chunks_to_dataframe(chunks_structured, "structured")
df_context_aware = chunks_to_dataframe(chunks_context_aware, "context_aware")

# Simpan dataframe ke CSV untuk digunakan dalam sistem RAG
df_structured.to_csv("uu_ketenagakerjaan_chunks_structured.csv", index=False)
df_context_aware.to_csv("uu_ketenagakerjaan_chunks_context_aware.csv", index=False)

print("Chunking selesai dan data disimpan ke CSV.")
# Out:
# Chunking selesai dan data disimpan ke CSV.

# %%
# =======================================
# Analisis distribusi chunk
# =======================================

print("\nAnalisis distribusi chunk structured:")
print(f"Jumlah chunks: {len(df_structured)}")
print(f"Rata-rata panjang chunk: {df_structured['text'].str.len().mean():.2f} karakter")
print(f"Min panjang chunk: {df_structured['text'].str.len().min()} karakter")
print(f"Max panjang chunk: {df_structured['text'].str.len().max()} karakter")

print("\nAnalisis distribusi chunk context aware:")
print(f"Jumlah chunks: {len(df_context_aware)}")
print(f"Rata-rata panjang chunk: {df_context_aware['text'].str.len().mean():.2f} karakter")
print(f"Min panjang chunk: {df_context_aware['text'].str.len().min()} karakter")
print(f"Max panjang chunk: {df_context_aware['text'].str.len().max()} karakter")

print("\nAnalisis referensi struktur:")
print(f"Jumlah BAB unik: {df_context_aware['bab'].nunique()}")
print(f"Jumlah Pasal unik: {df_context_aware['pasal'].nunique()}")
# Out:
# Analisis distribusi chunk structured:
# Jumlah chunks: 671
# Rata-rata panjang chunk: 168.44 karakter
# Min panjang chunk: 11 karakter
# Max panjang chunk: 1000 karakter
#
# Analisis distribusi chunk context aware:
# Jumlah chunks: 376
# Rata-rata panjang chunk: 444.72 karakter
# Min panjang chunk: 55 karakter
# Max panjang chunk: 1188 karakter
#
# Analisis referensi struktur:
# Jumlah BAB unik: 8
# Jumlah Pasal unik: 183

# %%
print("\nContoh chunks dari metode structured:")
print(df_structured.head(2)[["text", "bab", "pasal", "ayat"]].to_string())

print("\nContoh chunks dari metode context aware:")
print(df_context_aware.head(2)[["text", "bab", "pasal", "ayat"]].to_string())

# Fungsi untuk mencari chunk berdasarkan pasal
def search_chunks_by_pasal(df, pasal_number):
    return df[df['pasal'].str.contains(f"Pasal {pasal_number}", na=False)]

# Contoh pencarian pasal
pasal_to_search = 10  # Ganti dengan nomor pasal yang ingin dicari
print(f"\nContoh pencarian Pasal {pasal_to_search}:")
pasal_chunks = search_chunks_by_pasal(df_context_aware, pasal_to_search)
if not pasal_chunks.empty:
    print(pasal_chunks[["text", "bab", "pasal", "ayat"]].to_string())
else:
    print(f"Pasal {pasal_to_search} tidak ditemukan.")
# Out:
# Contoh chunks dari metode structured:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       text                    bab    pasal ayat
# 0           Dalam undang undang ini yang dimaksud dengan :\n1. Ketenagakerjaan adalah segala hal yang berhubungan dengan tenaga kerja\npada waktu sebelum, selama, dan sesudah masa kerja.\n2. Tenaga kerja adalah setiap orang yang mampu melakukan pekerjaan guna\nmenghasilkan barang dan/atau jasa baik untuk memenuhi kebutuh an\nsendiri maupun untuk masyarakat.\n3. Pekerja/buruh adalah setiap orang yang bekerja dengan menerima upah\natau imbalan dalam bentuk lain.\n4. Pemberi kerja adalah orang perseorangan, pengusaha, bada n hukum, atau\nbadan-badan lainnya yang mempekerjakan tenaga kerja dengan membayar\nupah atau imbalan dalam bentuk lain.\n5. Pengusaha adalah :\na. orang perseorangan, persekutuan, atau badan hukum yang menjalankan\nsuatu perusahaan milik sendiri;\nPRESIDEN\nREPUBLIK INDONESIA\n- 3 -\nb. orang pers eorangan, persekutuan, atau badan hukum yang secara\nberdiri sendiri menjalankan perusahaan bukan miliknya;\nc. orang perseorangan, persekutuan, atau badan hukum yang berada di  BAB I: KETENTUAN UMUM  Pasal 1
# 1  c. orang perseorangan, persekutuan, atau badan hukum yang berada di\nIndonesia mewakili perusahaan sebagaimana dimaksud dalam huruf a\ndan b yang berkedudukan di luar wilayah Indonesia.\n6. Perusahaan adalah :\na. setiap bentuk usaha yang berbadan hukum atau tidak, milik orang\nperseorangan, milik persekutuan, atau milik badan hukum, baik milik\nswasta maupun milik negara yang mempekerjakan pekerja/buruh\ndengan membayar upah atau imbalan dalam bentuk lain;\nb. usaha-usaha sosial dan usaha -usaha lain yang mempunyai pengurus\ndan mempekerjakan orang lain dengan membayar upah atau imbalan\ndalam bentuk lain.\n7. Perencanaan tenaga kerja adalah proses penyusunan renc ana\nketenagakerjaan secara sistematis yang dijadikan dasar dan acuan dalam\npenyusunan kebijakan, strategi, dan pelaksanaan program pembangunan\nketenagakerjaan yang berkesinambungan.\n8. Informasi ketenagakerjaan adalah gabungan, rangkaian, dan analisis data\nyang berbentuk angka yang telah diolah, naskah dan dokumen yang  BAB I: KETENTUAN UMUM  Pasal 1
#
# Contoh chunks dari metode context aware:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              text bab pasal ayat
# 0  PRESIDEN\nREPUBLIK INDONESIA\nUNDANG-UNDANG REPUBLIK INDONESIA\nNOMOR 13 TAHUN 2003\nTENTANG\nKETENAGAKERJAAN\nDENGAN RAHMAT TUHAN YANG MAHA ESA\nPRESIDEN REPUBLIK INDONESIA,\nMenimbang : a. bahwa pembangunan nasional dilaksanakan dalam rangka\npembangunan manusia Indonesia seutuhnya dan pembangunan\nmasyarakat Indonesia seluruhnya untuk mewujudkan masyarakat yang\nsejahtera, adil, makmur, yang merata, baik materiil maupun spiritual\nberdasarkan P ancasila dan Undang Undang Dasar Negara Republik\nIndonesia Tahun 1945;\nb. bahwa dalam pelaksanaan pembangunan nasional, tenaga kerja\nmempunyai peranan dan kedudukan yang sangat penting sebagai\npelaku dan tujuan pembangunan;\nc. bahwa sesuai dengan peranan d an kedudukan tenaga kerja, diperlukan\npembangunan ketenagakerjaan untuk meningkatkan kualitas tenaga\nkerja dan peransertanya dalam pembangunan serta peningkatan\nperlindungan tenaga kerja dan keluarganya sesuai dengan harkat dan\nmartabat kemanusiaan;\nd. bahwa perlindungan terhadap tenaga kerja dimaksudk
# 1                                                                                                                                                                 rja dan peransertanya dalam pembangunan serta peningkatan\nperlindungan tenaga kerja dan keluarganya sesuai dengan harkat dan\nmartabat kemanusiaan;\nd. bahwa perlindungan terhadap tenaga kerja dimaksudkan untuk\nmenjamin hak hak dasar pekerja/buruh dan menjamin kesamaan\nkesempatan serta perlakuan tanpa diskriminasi atas dasar apapun\nuntuk mewujudkan kesejahteraan pekerja/buruh dan keluarganya\ndengan tetap memperhatikan perkembangan kemajuan dunia usaha;\ne. bahwa beberapa undang undang di bidang ketenagakerjaan dipandang\nsudah tidak sesuai lagi dengan kebutuhan dan tuntutan pembangunan\nketenagakerjaan, oleh karena itu perlu dicabut dan/atau ditarik\nkembali;\nf. bahwa …\nPRESIDEN\nREPUBLIK INDONESIA\n- 2 -\nf. bahwa berdasarkan pertimbangan sebagaimana tersebut pada huruf a,\nb, c, d, dan e perlu membentuk Undang undang tentang\nKetenagakerjaan;
#
# Contoh pencarian Pasal 10:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            text             bab      pasal    ayat
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Pasal 10\n(1) Pelatihan kerja dilaksanakan dengan memperhatikan kebutuhan pasar kerja\ndan dunia usaha, baik di da-lam maupun di luar hubungan kerja.\n(2) Pelatihan kerja diselenggarakan berdasarkan program pelatihan yang\nmengacu pada standar kompetensi kerja.\n(3) Pelatihan kerja dapat dilakukan secara berjenjang.\n(4) Ketentuan mengenai tata cara penetapan sta ndar kompetensi kerja\n(2) diatur dengan Keputusan Menteri.    BAB III: ...   Pasal 10  Ayat 2
# 129                                                                                                                                                                                                                                                                                                                                                                                                            Pasal 100\n(1) Untuk meningkatkan kesejahteraan bagi pekerja/buruh dan keluarganya,\npengusaha wajib menyediakan fasilitas kesejahteraan.\n(2) Penyediaan fasilitas kesejahteraan sebagaimana dimaksud dalam ayat (1),\ndilaksanakan dengan memperhatikan kebutuhan pekerja/buruh dan ukuran\nkemampuan perusahaan.\n(3) Ketentuan mengenai jenis dan kriteria fasilitas kesejahteraan sesuai dengan\nkebutuhan pekerja/buruh dan ukuran kemampuan perusahaan sebagaimana\n(1) dan ayat (2), diatur dengan Peraturan Pemerintah.    BAB VII: ...  Pasal 100  Ayat 1
# 130                                                                                                                                                                                                                                                                                                  Pasal 101\n(1) Untuk meningkatkan kesejahteraan pekerja/buruh, dibentuk koperasi\npekerja/buruh dan usaha-usaha produktif di perusahaan.\n(2) Pemerintah, pengusaha, dan pekerja/buruh atau serikat pekerja/serikat\nburuh berupaya menumbuhkembangkan koperasi pekerja/buruh, dan\nmengembangkan usaha produktif sebagaimana dimaksud dalam ayat (1).\n(3) Pembentukan koperasi sebagaimana dimaksud dalam ayat (1),\ndilaksanakan sesuai dengan peraturan perundang -undangan yang\nberlaku.\n(4) Upaya-upaya untuk menumbuhkembangkan koperasi pekerja/buruh\nsebagaimana dimaksud dalam ayat (2), diatur dengan Peraturan\nPemerintah.    BAB VII: ...  Pasal 101  Ayat 4
# 132  Pasal 102\n(1) Dalam melaksanakan hubungan industrial, pemerintah mempunyai fungsi\nmenetapkan kebijakan, memberikan pelayanan, melaksanakan\npengawasan, dan melakukan penindakan terhadap pelanggaran peraturan\nperundang-undangan ketenagakerjaan.\n(2) Dalam melaksanakan hubungan indus trial, pekerja/buruh dan serikat\npekerja/serikat buruhnya mempunyai fungsi menjalankan pekerjaan sesuai\ndengan kewajibannya, menjaga ketertiban demi kelangsungan produksi,\nmenyalurkan aspirasi secara demokratis, mengembangkan keterampilan,\ndan keahliannya serta ikut memajukan perusahaan dan memperjuangkan\nkesejahteraan anggota beserta keluarganya.\n(3) Dalam melaksanakan hubungan industrial, pengusaha dan organisasi\npengusahanya mempunyai fungsi menciptakan kemitraan, mengembang -\nkan usaha, memperluas lapang an kerja, dan memberikan kesejahteraan\npekerja/buruh secara terbuka, demokratis, dan berkeadilan.     BAB XI: ...  Pasal 102  Ayat 3
# 133                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Pasal 103\nHubungan Industrial dilaksanakan melalui sarana :\na. serikat pekerja/serikat buruh;\nb. organisasi pengusaha;\nc. lembaga kerja sama bipartit;\nd. embaga kerja sama tripartit;\ne. peraturan perusahaan;\nf. perjanjian kerja bersama;\ng. peraturan perundang-undangan ketenagakerjaan; dan\nh. lembaga penyelesaian perselisihan hubungan industrial.\nBagian ...\nPRESIDEN\nREPUBLIK INDONESIA\n- 42 -\nBagian Kedua\nSerikat Pekerja/Serikat Buruh     BAB XI: ...  Pasal 103    None
# 134                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Pasal 104\n(1) Setiap pekerja/buruh berhak membentuk dan menjadi anggota serikat\npekerja/serikat buruh.     BAB XI: ...  Pasal 104  Ayat 1
# 135                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Pasal 102\nserikat pekerja/serikat buruh ber -hak menghimpun dan mengelola\nkeuangan serta mempertanggungjawabkan keuangan organisasi termasuk\ndana mogok.\n(3) Besarnya dan tata cara pemungutan dana mogok sebagaimana dimaksud\n(2) diatur dalam ang -garan dasar dan/atau anggaran rumah\ntangga serikat pekerja/serikat buruh yang bersangkutan.\nBagian Ketiga\nOrganisasi Pengusaha     BAB XI: ...  Pasal 102  Ayat 2
# 136                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Pasal 105\n(1) Setiap pengusaha berhak membentuk dan menjadi anggota organisasi\npengusaha.\n(2) Ketentuan mengenai organisasi pengusaha diatur sesuai dengan peraturan\nperundang-undangan yang ber-laku.\nBagian Keempat\nLembaga Kerja Sama Bipartit     BAB XI: ...  Pasal 105  Ayat 2
# 137                                                                                                                        Pasal 106\n(1) Setiap perusahaan yang mempekerjakan 50 (lima puluh) orang pekerja/\nburuh atau lebih wajib membentuk lembaga kerja sama bipartit.\n(2) Lembaga kerja sama bipartit sebagaimana dimaksud dalam ayat (1)\nberfungsi sebagai forum komunikasi, dan konsultasi mengen ai hal\nketenagakerjaan di perusahaan.\n(3) Susunan ...\nPRESIDEN\nREPUBLIK INDONESIA\n- 43 -\n(3) Susunan keanggotaan lembaga kerja sama bipartit sebagaimana dimaksud\n(2) terdiri dari unsur pengusaha dan unsur pekerja/buruh yang\nditunjuk oleh pekerja/buruh secara demokratis untuk mewakili kepentingan\npekerja/buruh di perusahaan yang bersangkutan.\n(4) Ketentuan mengenai tata cara pembentukan dan susunan keanggotaan\n(1) dan\n(3) diatur dengan Keputusan Menteri.\nBagian Kelima\nLembaga Kerja Sama Tripartit     BAB XI: ...  Pasal 106  Ayat 3
# 138                                                                                                                                                                                        Pasal 107\n(1) Lembaga kerja sama tripartit memberikan pertimbangan, saran, dan\npendapat kepada pemerintah dan pihak terkait dalam penyusunan\nkebijakan dan pemecahan masalah ketenagakerjaan.\n(2) Lembaga Kerja sama Tripa rtit sebagaimana dimaksud dalam ayat (1),\nterdiri dari :\na. Lembaga Kerja sama Tripartit Nasional, Provinsi, dan Kabupaten/\nKota; dan\nb. Lembaga Kerja sama Tripartit Sektoral Nasional, Provinsi, dan\nKabupaten/Kota.\n(3) Keanggotaan Lembaga Kerja sama Tripartit terdiri dari unsur pemerintah,\norganisasi pengusaha, dan seri-kat pekerja/serikat buruh.\n(4) Tata kerja dan susunan organisasi Lembaga Kerja sama Tripartit\n(1) diatur dengan Peraturan Pemerintah.\nBagian Keenam\nPeraturan Perusahaan     BAB XI: ...  Pasal 107  Ayat 1
# 139                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Pasal 108\n(1) Pengusaha yang mempekerjakan pekerja/buruh sekurang -kurangnya 10\n(sepuluh) orang wajib membuat peraturan perusahaan yang mulai berlaku\nsetelah disahkan oleh Menteri atau pejabat yang ditunjuk.\n(2) Kewajiban ...\nPRESIDEN\nREPUBLIK INDONESIA\n- 44 -\n(2) Kewajiban membuat peraturan perusahaan sebagaimana dimaksud dalam\n(1) tidak berlaku bagi peru -sahaan yang telah memiliki perjanjian\nkerja bersama.     BAB XI: ...  Pasal 108  Ayat 1
# 140                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Pasal 109\nPeraturan perusahaan disusun oleh dan menjadi tanggung jawab dari pe ngusaha\nyang bersangkutan.     BAB XI: ...  Pasal 109    None
# 288                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Pasal 10\nAyat (1)\nCukup jelas\nAyat (2)\nPenetapan standar kompetensi kerja dilakukan oleh Menteri dengan\nmengikutsertakan sektor terkait.\nAyat (3)\nJenjang pelatihan kerja pada umumnya terdiri atas tingkat dasar, terampil, dan\nahli.\nAyat (4)\nCukup jelas  BAB XVIII: ...   Pasal 10    None
# 340                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Pasal 100\nAyat (1)\nYang dimaksud dengan fasilitas kesejahteraan antara lain pelayanan keluarga\nberencana, tempat penitipan anak, perumahan pekerja/buruh, fasilitas\nberibadah, fasilitas olah raga, fasilitas kantin, fasilitas kesehatan, dan fasilitas\nrekreasi.\nAyat (2)\nCukup jelas\nAyat (3)\nCukup jelas  BAB XVIII: ...  Pasal 100    None
# 341                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Pasal 101\nAyat (1)\nYang dimaksud dengan usaha -usaha produktif di perusahaan adalah kegiatan\nyang bersifat ekonomis yang menghasilkan pendapatan di luar upah.\nAyat (2)\nCukup jelas\nAyat (3)\nCukup jelas\nAyat (4)\nCukup jelas  BAB XVIII: ...  Pasal 101    None
# 342                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Pasal 104\nAyat (1)\nKebebasan untuk membentuk, masuk atau tidak masuk menjadi anggota serikat\npekerja/serikat buruh merupakan salah satu hak dasar pekerja/buruh.\nPRESIDEN\nREPUBLIK INDONESIA\n- 34 -\nAyat (2)\nCukup jelas\nAyat (3)\nCukup jelas  BAB XVIII: ...  Pasal 104    None
# 343                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Pasal 106\nAyat (1)\nada perusahaan dengan jumlah pekerja/buruh kurang dari 50 (lima puluh)\norang, komunikasi dan konsultasi masih dapat dilakukan secara individual\ndengan baik dan efek tif. Pada perusahaan dengan jumlah pekerja/buruh 50\n(lima puluh) orang atau lebih, komunikasi dan konsultasi perlu dilakukan\nmelalui sistem perwakilan.\nAyat (2)\nCukup jelas\nAyat (3)\nCukup jelas\nAyat (4)\nCukup jelas  BAB XVIII: ...  Pasal 106    None
